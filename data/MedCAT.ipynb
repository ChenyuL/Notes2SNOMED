# %%
# Install medcat
! pip install medcat~=1.10.0
try:
    from medcat.cat import CAT
except:
    print("WARNING: Runtime will restart automatically and please run other cells thereafter.")
    exit()

# %%
import gensim
import pandas as pd
import numpy as np
from tokenizers import ByteLevelBPETokenizer
from gensim.models import Word2Vec

# %%
pip install ByteLevelBPETokenizer
# Out:
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# ERROR: Could not find a version that satisfies the requirement ByteLevelBPETokenizer (from versions: none)
# ERROR: No matching distribution found for ByteLevelBPETokenizer
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from sentence_transformers import SentenceTransformer
sentences = ["Cat scratch injury", "Cat scratch disease", "Bartonellosis"]

model = SentenceTransformer('FremyCompany/BioLORD-2023')
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 from sentence_transformers import SentenceTransformer
#       2 sentences = ["Cat scratch injury", "Cat scratch disease", "Bartonellosis"]
# ----> 4 model = SentenceTransformer('FremyCompany/BioLORD-2023')
#       5 embeddings = model.encode(sentences)
#       6 print(embeddings)
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:194, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, cache_folder, trust_remote_code, revision, token, use_auth_token)
#     191         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     193 if is_sentence_transformer_model(model_name_or_path, token, cache_folder=cache_folder, revision=revision):
# --> 194     modules = self._load_sbert_model(
#     195         model_name_or_path,
#     196         token=token,
#     197         cache_folder=cache_folder,
#     198         revision=revision,
#     199         trust_remote_code=trust_remote_code,
#     200     )
#     201 else:
#     202     modules = self._load_auto_model(
#     203         model_name_or_path,
#     204         token=token,
#    (...)
#     207         trust_remote_code=trust_remote_code,
#     208     )
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1060, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code)
#    1058     else:
#    1059         kwargs["tokenizer_args"] = hub_kwargs
# -> 1060     module = Transformer(model_name_or_path, cache_dir=cache_folder, **kwargs)
#    1061 else:
#    1062     # Normalize does not require any files to be loaded
#    1063     if module_class == Normalize:
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:38, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, cache_dir, tokenizer_args, do_lower_case, tokenizer_name_or_path)
#      35 config = AutoConfig.from_pretrained(model_name_or_path, **model_args, cache_dir=cache_dir)
#      36 self._load_model(model_name_or_path, config, cache_dir, **model_args)
# ---> 38 self.tokenizer = AutoTokenizer.from_pretrained(
#      39     tokenizer_name_or_path if tokenizer_name_or_path is not None else model_name_or_path,
#      40     cache_dir=cache_dir,
#      41     **tokenizer_args,
#      42 )
#      44 # No max_seq_length set. Try to infer from model
#      45 if max_seq_length is None:
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:814, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     810     if tokenizer_class is None:
#     811         raise ValueError(
#     812             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#     813         )
# --> 814     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     816 # Otherwise we have to be creative.
#     817 # if model is an encoder decoder, the encoder tokenizer class is used by default
#     818 if isinstance(config, EncoderDecoderConfig):
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2029, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, *init_inputs, **kwargs)
#    2026     else:
#    2027         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2029 return cls._from_pretrained(
#    2030     resolved_vocab_files,
#    2031     pretrained_model_name_or_path,
#    2032     init_configuration,
#    2033     *init_inputs,
#    2034     token=token,
#    2035     cache_dir=cache_dir,
#    2036     local_files_only=local_files_only,
#    2037     _commit_hash=commit_hash,
#    2038     _is_local=is_local,
#    2039     **kwargs,
#    2040 )
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2261, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, *init_inputs, **kwargs)
#    2259 # Instantiate the tokenizer.
#    2260 try:
# -> 2261     tokenizer = cls(*init_inputs, **init_kwargs)
#    2262 except OSError:
#    2263     raise OSError(
#    2264         "Unable to load vocabulary from file. "
#    2265         "Please check that the provided vocabulary is accessible and not corrupted."
#    2266     )
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/models/mpnet/tokenization_mpnet_fast.py:139, in MPNetTokenizerFast.__init__(self, vocab_file, tokenizer_file, do_lower_case, bos_token, eos_token, sep_token, cls_token, unk_token, pad_token, mask_token, tokenize_chinese_chars, strip_accents, **kwargs)
#     136 # Mask token behave like a normal word, i.e. include the space before it
#     137 mask_token = AddedToken(mask_token, lstrip=True, rstrip=False) if isinstance(mask_token, str) else mask_token
# --> 139 super().__init__(
#     140     vocab_file,
#     141     tokenizer_file=tokenizer_file,
#     142     do_lower_case=do_lower_case,
#     143     bos_token=bos_token,
#     144     eos_token=eos_token,
#     145     sep_token=sep_token,
#     146     cls_token=cls_token,
#     147     unk_token=unk_token,
#     148     pad_token=pad_token,
#     149     mask_token=mask_token,
#     150     tokenize_chinese_chars=tokenize_chinese_chars,
#     151     strip_accents=strip_accents,
#     152     **kwargs,
#     153 )
#     155 pre_tok_state = json.loads(self.backend_tokenizer.normalizer.__getstate__())
#     156 if (
#     157     pre_tok_state.get("lowercase", do_lower_case) != do_lower_case
#     158     or pre_tok_state.get("strip_accents", strip_accents) != strip_accents
#     159 ):
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:162, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     156 super().__init__(**kwargs)
#     158 # The following logic will be replace with a single add_tokens once a fix is pushed to tokenizers
#     159 # allows converting a slow -> fast, non-legacy: if the `tokenizer.json` does not have all the added tokens
#     160 # uses the information stored in `added_tokens_decoder`.
#     161 # this is costly for fast tokenizers as we re-compute the regex again. But not all tokens are added tokens
# --> 162 tokens_to_add = [
#     163     token
#     164     for index, token in sorted(added_tokens_decoder.items(), key=lambda x: x[0])
#     165     if token not in self.added_tokens_decoder
#     166 ]
#     167 encoder = list(self.added_tokens_encoder.keys()) + [str(token) for token in tokens_to_add]
#     168 # if some of the special tokens are strings, we check if we don't already have a token
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:165, in <listcomp>(.0)
#     156 super().__init__(**kwargs)
#     158 # The following logic will be replace with a single add_tokens once a fix is pushed to tokenizers
#     159 # allows converting a slow -> fast, non-legacy: if the `tokenizer.json` does not have all the added tokens
#     160 # uses the information stored in `added_tokens_decoder`.
#     161 # this is costly for fast tokenizers as we re-compute the regex again. But not all tokens are added tokens
#     162 tokens_to_add = [
#     163     token
#     164     for index, token in sorted(added_tokens_decoder.items(), key=lambda x: x[0])
# --> 165     if token not in self.added_tokens_decoder
#     166 ]
#     167 encoder = list(self.added_tokens_encoder.keys()) + [str(token) for token in tokens_to_add]
#     168 # if some of the special tokens are strings, we check if we don't already have a token
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:236, in PreTrainedTokenizerFast.added_tokens_decoder(self)
#     228 @property
#     229 def added_tokens_decoder(self) -> Dict[int, AddedToken]:
#     230     """
#     231     Returns the added tokens in the vocabulary as a dictionary of index to AddedToken.
#     232
#     233     Returns:
#     234         `Dict[str, int]`: The added tokens.
#     235     """
# --> 236     return self._tokenizer.get_added_tokens_decoder()
#
# AttributeError: 'tokenizers.Tokenizer' object has no attribute 'get_added_tokens_decoder'

# %%
pip install sentence_transformers
# Out:
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: sentence_transformers in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (4.37.2)
# Requirement already satisfied: tqdm in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (2.0.1)
# Requirement already satisfied: numpy in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (1.26.3)
# Requirement already satisfied: scikit-learn in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (1.3.0)
# Requirement already satisfied: scipy in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: nltk in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sentence_transformers) (9.5.0)
# Requirement already satisfied: filelock in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: click in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from nltk->sentence_transformers) (8.1.6)
# Requirement already satisfied: joblib in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tokenizers
# Out:
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: tokenizers in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (0.15.2)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from tokenizers) (0.20.3)
# Requirement already satisfied: filelock in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (2023.6.0)
# Requirement already satisfied: requests in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (2024.2.2)
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/chenyuli/anaconda3/envs/py3/lib/python3.11/site-packages/pickleshare-0.7.5.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# Sentences we want sentence embeddings for
sentences = ["Cat scratch injury", "Cat scratch disease", "Bartonellosis"]

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('FremyCompany/BioLORD-2023')
model = AutoModel.from_pretrained('FremyCompany/BioLORD-2023')

# Tokenize sentences
encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)
# Perform pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)
print("Sentence embeddings:")
print(sentence_embeddings)
# Out:
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# Ignored unknown kwarg option special
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 15
#      12 sentences = ["Cat scratch injury", "Cat scratch disease", "Bartonellosis"]
#      14 # Load model from HuggingFace Hub
# ---> 15 tokenizer = AutoTokenizer.from_pretrained('FremyCompany/BioLORD-2023')
#      16 model = AutoModel.from_pretrained('FremyCompany/BioLORD-2023')
#      18 # Tokenize sentences
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:814, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     810     if tokenizer_class is None:
#     811         raise ValueError(
#     812             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#     813         )
# --> 814     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     816 # Otherwise we have to be creative.
#     817 # if model is an encoder decoder, the encoder tokenizer class is used by default
#     818 if isinstance(config, EncoderDecoderConfig):
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2029, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, *init_inputs, **kwargs)
#    2026     else:
#    2027         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2029 return cls._from_pretrained(
#    2030     resolved_vocab_files,
#    2031     pretrained_model_name_or_path,
#    2032     init_configuration,
#    2033     *init_inputs,
#    2034     token=token,
#    2035     cache_dir=cache_dir,
#    2036     local_files_only=local_files_only,
#    2037     _commit_hash=commit_hash,
#    2038     _is_local=is_local,
#    2039     **kwargs,
#    2040 )
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2261, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, *init_inputs, **kwargs)
#    2259 # Instantiate the tokenizer.
#    2260 try:
# -> 2261     tokenizer = cls(*init_inputs, **init_kwargs)
#    2262 except OSError:
#    2263     raise OSError(
#    2264         "Unable to load vocabulary from file. "
#    2265         "Please check that the provided vocabulary is accessible and not corrupted."
#    2266     )
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/models/mpnet/tokenization_mpnet_fast.py:139, in MPNetTokenizerFast.__init__(self, vocab_file, tokenizer_file, do_lower_case, bos_token, eos_token, sep_token, cls_token, unk_token, pad_token, mask_token, tokenize_chinese_chars, strip_accents, **kwargs)
#     136 # Mask token behave like a normal word, i.e. include the space before it
#     137 mask_token = AddedToken(mask_token, lstrip=True, rstrip=False) if isinstance(mask_token, str) else mask_token
# --> 139 super().__init__(
#     140     vocab_file,
#     141     tokenizer_file=tokenizer_file,
#     142     do_lower_case=do_lower_case,
#     143     bos_token=bos_token,
#     144     eos_token=eos_token,
#     145     sep_token=sep_token,
#     146     cls_token=cls_token,
#     147     unk_token=unk_token,
#     148     pad_token=pad_token,
#     149     mask_token=mask_token,
#     150     tokenize_chinese_chars=tokenize_chinese_chars,
#     151     strip_accents=strip_accents,
#     152     **kwargs,
#     153 )
#     155 pre_tok_state = json.loads(self.backend_tokenizer.normalizer.__getstate__())
#     156 if (
#     157     pre_tok_state.get("lowercase", do_lower_case) != do_lower_case
#     158     or pre_tok_state.get("strip_accents", strip_accents) != strip_accents
#     159 ):
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:162, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     156 super().__init__(**kwargs)
#     158 # The following logic will be replace with a single add_tokens once a fix is pushed to tokenizers
#     159 # allows converting a slow -> fast, non-legacy: if the `tokenizer.json` does not have all the added tokens
#     160 # uses the information stored in `added_tokens_decoder`.
#     161 # this is costly for fast tokenizers as we re-compute the regex again. But not all tokens are added tokens
# --> 162 tokens_to_add = [
#     163     token
#     164     for index, token in sorted(added_tokens_decoder.items(), key=lambda x: x[0])
#     165     if token not in self.added_tokens_decoder
#     166 ]
#     167 encoder = list(self.added_tokens_encoder.keys()) + [str(token) for token in tokens_to_add]
#     168 # if some of the special tokens are strings, we check if we don't already have a token
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:165, in <listcomp>(.0)
#     156 super().__init__(**kwargs)
#     158 # The following logic will be replace with a single add_tokens once a fix is pushed to tokenizers
#     159 # allows converting a slow -> fast, non-legacy: if the `tokenizer.json` does not have all the added tokens
#     160 # uses the information stored in `added_tokens_decoder`.
#     161 # this is costly for fast tokenizers as we re-compute the regex again. But not all tokens are added tokens
#     162 tokens_to_add = [
#     163     token
#     164     for index, token in sorted(added_tokens_decoder.items(), key=lambda x: x[0])
# --> 165     if token not in self.added_tokens_decoder
#     166 ]
#     167 encoder = list(self.added_tokens_encoder.keys()) + [str(token) for token in tokens_to_add]
#     168 # if some of the special tokens are strings, we check if we don't already have a token
#
# File ~/anaconda3/envs/py3/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:236, in PreTrainedTokenizerFast.added_tokens_decoder(self)
#     228 @property
#     229 def added_tokens_decoder(self) -> Dict[int, AddedToken]:
#     230     """
#     231     Returns the added tokens in the vocabulary as a dictionary of index to AddedToken.
#     232
#     233     Returns:
#     234         `Dict[str, int]`: The added tokens.
#     235     """
# --> 236     return self._tokenizer.get_added_tokens_decoder()
#
# AttributeError: 'tokenizers.Tokenizer' object has no attribute 'get_added_tokens_decoder'
